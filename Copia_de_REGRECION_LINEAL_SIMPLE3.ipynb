# %% [markdown]
# Conjunto de datos de productividad de desarrolladores de la IA

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv('ai_dev_productivity.csv')

# %%
data.head()
# Out:
#    hours_coding  coffee_intake_mg  ...  cognitive_load  task_success
# 0          5.99               600  ...             5.4             1
# 1          4.72               568  ...             4.7             1
# 2          6.30               560  ...             2.2             1
# 3          8.05               600  ...             5.9             0
# 4          4.53               421  ...             6.3             1
#
# [5 rows x 9 columns]

# %%
data.describe()
# Out:
#        hours_coding  coffee_intake_mg  ...  cognitive_load  task_success
# count    500.000000        500.000000  ...      500.000000    500.000000
# mean       5.015600        463.192000  ...        4.498200      0.606000
# std        1.947253        142.334991  ...        1.868861      0.489124
# min        0.000000          6.000000  ...        1.000000      0.000000
# 25%        3.600000        369.500000  ...        3.175000      0.000000
# 50%        5.030000        500.500000  ...        4.400000      1.000000
# 75%        6.275000        600.000000  ...        5.800000      1.000000
# max       12.000000        600.000000  ...       10.000000      1.000000
#
# [8 rows x 9 columns]

# %%
data.hist(bins=50,figsize=(20,15))
plt.show()

# %%
#asignamos nuestra variable dy.e entrada por entrenamiento y las etiquetas y.
datax=[["hours_coding"]]
x_train= data[["hours_coding"]].values
y_train=data["sleep_hours"].values

# %%
# Creamos el objetivode regresion linear
regr=linear_model.LinearRegression()

# Entrenamos nuestro modelo
regr.fit(x_train, y_train)

# Hacemos las predicciones que en definitiva una linea (en este caso,al ser 2D)
Y_pred = regr.predict(x_train)

# Veamos los coeficientes obtenidos, En nuestro caso,seran la Tangente
print('Coeficientes: \n', regr.coef_)
# Este es el valor donde corta el ejey(en x=0)
print(' independiente: \n', regr.intercept_)
# Error Cuadrado Medio
print("Mean squared error:%.2f"% mean_squared_error(y_train,Y_pred))
# Puntaje de Varianza. El mejor puntaje es un 1.0
print('Variance score: %.2f' % r2_score(y_train,Y_pred))

# Veamos los coeficientes
print('Coeficientes: \n', regr.coef_)
# e
# Out:
# Coeficientes:
#  [-0.01898004]
#  independiente:
#  7.070996292722618
# Mean squared error:2.11
# Variance score: 0.00
# Coeficientes:
#  [-0.01898004]

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Productivity Data')
plt.show()
# Out:
# Correlation Matrix:
#                   hours_coding  coffee_intake_mg  distractions  sleep_hours  \
# hours_coding          1.000000          0.889816     -0.009800    -0.025385
# coffee_intake_mg      0.889816          1.000000     -0.036370    -0.038990
# distractions         -0.009800         -0.036370      1.000000     0.041339
# sleep_hours          -0.025385         -0.038990      0.041339     1.000000
# commits               0.646830          0.561182     -0.042685    -0.054519
# bugs_reported         0.055979          0.046261     -0.008341    -0.384424
# ai_usage_hours        0.571882          0.465367      0.029137    -0.084018
# cognitive_load        0.050906          0.036878      0.400058    -0.734054
# task_success          0.615528          0.695185     -0.104303     0.186662
#
#                    commits  bugs_reported  ai_usage_hours  cognitive_load  \
# hours_coding      0.646830       0.055979        0.571882        0.050906
# ...

# %%
data=pd.read_csv('ai_dev_productivity.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-3002672939.py in <cell line: 0>()
# ----> 1 data=pd.read_csv('ai_dev_productivity.csv')
#
# NameError: name 'pd' is not defined

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Productivity Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-150879744.py in <cell line: 0>()
#       1 # Calculate the correlation matrix
# ----> 2 correlation_matrix = data.corr()
#       3
#       4 # Print the correlation matrix
#       5 print("Correlation Matrix:")
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# %%
data=pd.read_csv('ai_dev_productivity.csv')

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Productivity Data')
plt.show()
# Out:
# Correlation Matrix:
#                   hours_coding  coffee_intake_mg  distractions  sleep_hours  \
# hours_coding          1.000000          0.889816     -0.009800    -0.025385
# coffee_intake_mg      0.889816          1.000000     -0.036370    -0.038990
# distractions         -0.009800         -0.036370      1.000000     0.041339
# sleep_hours          -0.025385         -0.038990      0.041339     1.000000
# commits               0.646830          0.561182     -0.042685    -0.054519
# bugs_reported         0.055979          0.046261     -0.008341    -0.384424
# ai_usage_hours        0.571882          0.465367      0.029137    -0.084018
# cognitive_load        0.050906          0.036878      0.400058    -0.734054
# task_success          0.615528          0.695185     -0.104303     0.186662
#
#                    commits  bugs_reported  ai_usage_hours  cognitive_load  \
# hours_coding      0.646830       0.055979        0.571882        0.050906
# ...

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Productivity Data')
plt.show()
# Out:
# Correlation Matrix:
#                   hours_coding  coffee_intake_mg  distractions  sleep_hours  \
# hours_coding          1.000000          0.889816     -0.009800    -0.025385
# coffee_intake_mg      0.889816          1.000000     -0.036370    -0.038990
# distractions         -0.009800         -0.036370      1.000000     0.041339
# sleep_hours          -0.025385         -0.038990      0.041339     1.000000
# commits               0.646830          0.561182     -0.042685    -0.054519
# bugs_reported         0.055979          0.046261     -0.008341    -0.384424
# ai_usage_hours        0.571882          0.465367      0.029137    -0.084018
# cognitive_load        0.050906          0.036878      0.400058    -0.734054
# task_success          0.615528          0.695185     -0.104303     0.186662
#
#                    commits  bugs_reported  ai_usage_hours  cognitive_load  \
# hours_coding      0.646830       0.055979        0.571882        0.050906
# ...

# %%
# Create a scatter plot of 'hours_coding' vs 'sleep_hours'
plt.figure(figsize=(10, 6))
sb.regplot(x='hours_coding', y='sleep_hours', data=data)

# Add titles and labels
plt.title('Linear Regression of Sleep Hours vs. Hours Coding')
plt.xlabel('Hours Coding')
plt.ylabel('Sleep Hours')

# Show the plot
plt.show()
